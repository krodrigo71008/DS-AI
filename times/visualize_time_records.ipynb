# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Control Thread

# %%
control_thread_df = pd.read_csv("control_thread.csv")
control_thread_df /= 1000000 # convert ns to ms
control_thread_df.describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.95, 0.99])
# Out:
#                dt
# count  454.000000
# mean    35.681623
# std     31.318200
# min      1.004600
# 25%     17.643400
# 50%     32.851100
# 75%     45.990925
# 90%     61.878780
# 95%     69.720910
# 99%     89.607823
# max    462.438100

# %%
control_thread_df["dt"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Perception

# %%
perception_df = pd.read_csv("perception.csv")
perception_df /= 1000000 # convert ns to ms
perception_df.describe()
# Out:
#        screenshot   hide_huds  process_frame  create_objects  \
# count  426.000000  426.000000     426.000000      426.000000
# mean    35.452992    1.524895      68.118370        0.061938
# std      5.666724    0.535156       6.745695        0.250331
# min     23.005000    0.000000      56.901600        0.000000
# 25%     31.007900    1.001025      64.567450        0.000000
# 50%     35.547750    1.505200      67.386550        0.000000
# 75%     39.590050    2.001900      70.714550        0.000000
# max     52.640900    2.961000     160.793200        1.504400
#
#        put_in_debug_queue
# count          426.000000
# mean            35.681503
# std             10.046851
# min             18.101000
# 25%             31.561175
# 50%             35.439800
# 75%             39.369650
# max            204.376100

# %%
perception_df["screenshot"].hist()
# Out:
# <AxesSubplot:>

# %%
perception_df["hide_huds"].hist()
# Out:
# <AxesSubplot:>

# %%
perception_df["process_frame"].hist()
# Out:
# <AxesSubplot:>

# %%
perception_df["create_objects"].hist()
# Out:
# <AxesSubplot:>

# %%
perception_df["put_in_debug_queue"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Segmentation

# %%
segmentation_df = pd.read_csv("segmentation.csv")
segmentation_df /= 1000000 # convert ns to ms
segmentation_df.describe()
# Out:
#        screenshot  process_frame  put_in_debug_queue
# count  276.000000     276.000000          276.000000
# mean    35.428820     181.376411            0.070946
# std      6.658603      11.459679            0.305556
# min     23.684400     157.595400            0.000000
# 25%     30.472475     175.548825            0.000000
# 50%     34.863950     180.926200            0.000000
# 75%     39.717425     185.576450            0.000000
# max     62.690500     325.793000            3.023700

# %%
segmentation_df["screenshot"].hist()
# Out:
# <AxesSubplot:>

# %%
segmentation_df["process_frame"].hist()
# Out:
# <AxesSubplot:>

# %%
segmentation_df["put_in_debug_queue"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Modeling

# %%
modeling_df = pd.read_csv("modeling.csv")
modeling_df /= 1000000 # convert ns to ms
modeling_df.describe()
# Out:
#        handle_detected_objects_queue  handle_segmentation_queue  update_clock  \
# count                     420.000000                 420.000000    420.000000
# mean                        5.997984                   2.033400      0.024512
# std                         8.514697                   3.440686      0.168483
# min                         0.000000                   0.000000      0.000000
# 25%                         0.000000                   0.000000      0.000000
# 50%                         1.006450                   1.998450      0.000000
# 75%                        11.093225                   2.826425      0.000000
# max                        35.831800                  33.895100      1.454700
#
#        update_world_model  update_player_model  slam_predict  \
# count          420.000000           420.000000    420.000000
# mean             0.027952             1.778358      0.073065
# std              0.171646             1.978838      0.276044
# ...

# %%
modeling_df["handle_detected_objects_queue"].hist()
# Out:
# <AxesSubplot:>

# %%
modeling_df["handle_segmentation_queue"].hist()
# Out:
# <AxesSubplot:>

# %%
modeling_df["update_clock"].hist()
# Out:
# <AxesSubplot:>

# %%
modeling_df["update_world_model"].hist()
# Out:
# <AxesSubplot:>

# %%
modeling_df["update_player_model"].hist()
# Out:
# <AxesSubplot:>

# %%
modeling_df["slam_predict"].hist()
# Out:
# <AxesSubplot:>

# %%
modeling_df["use_received_yolo_info"].hist()
# Out:
# <AxesSubplot:>

# %%
modeling_df["use_received_segmentation_info"].hist()
# Out:
# <AxesSubplot:>

# %%
modeling_slam_df = pd.read_csv("modeling_slam_dts.csv")
modeling_slam_df.describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.85, 0.9, 0.95, 0.975, 0.99, 0.999])
# Out:
#           slam_dt
# count  420.000000
# mean     0.142879
# std      0.109438
# min      0.003521
# 25%      0.027483
# 50%      0.146651
# 75%      0.219724
# 80%      0.239877
# 85%      0.262209
# 90%      0.273241
# 95%      0.295873
# 97.5%    0.326377
# 99%      0.359736
# 99.9%    0.732645
# max      0.941237

# %%
modeling_slam_phases_df = pd.read_csv("modeling_slam_phases_dts.csv")
modeling_slam_phases_df /= 1000000 # convert ns to ms
modeling_slam_phases_df.describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.85, 0.9, 0.95, 0.975, 0.99, 0.999])
# Out:
#                p1          p2
# count  422.000000  422.000000
# mean    31.009615    0.640664
# std     18.287024    0.569310
# min      2.509300    0.000000
# 25%     16.181550    0.000000
# 50%     27.054550    0.999500
# 75%     45.234225    1.009075
# 80%     48.840840    1.030960
# 85%     53.296205    1.189840
# 90%     58.748130    1.322400
# 95%     63.610520    1.461345
# 97.5%   69.471442    1.506190
# 99%     73.685814    1.511332
# 99.9%   79.711045    2.007375
# max     80.283100    2.014700

# %% [markdown]
# ### Player Model

# %%
player_model_df = pd.read_csv("player_model.csv")
player_model_df /= 1000000 # convert ns to ms
player_model_df.describe()
# Out:
#             update
# count  1526.000000
# mean      0.248262
# std       0.652510
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       3.763800

# %%
player_model_df["update"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### World Model

# %%
world_model_df = pd.read_csv("world_model.csv")
world_model_df["time"] /= 1000000 # converting from ns to ms
world_model_times = {k: v for (k, v) in world_model_df.groupby('type')}

# %%
for name, time_df in world_model_times.items():
    print(name)
    print(time_df.describe())
    print("\n\n")
# Out:
# add_object
#              time
# count  190.000000
# mean     0.035731
# std      0.187675
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.275700
#
#
#
# create_object
#               time
# count  1187.000000
# mean      7.739166
# std       1.676386
# min       0.998800
# 25%       6.742950
# 50%       7.535400
# 75%       8.532950
# max      16.788000
#
#
#
# decide_player_position
#              time
# count  310.000000
# mean     0.037447
# std      0.209432
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.505400
#
#
#
# finish_cycle
#              time
# count  310.000000
# mean     0.729577
# std      0.709789
# min      0.000000
# 25%      0.000000
# 50%      0.999200
# 75%      1.008125
# max      3.003400
#
#
#
# get_all_of
#               time
# count  2644.000000
# mean      0.020587
# std       0.145131
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# ...

# %%
for name, time_df in world_model_times.items():
    plt.figure()
    axes = time_df["time"].hist()
    axes.set_title(name)

# %% [markdown]
# ### Decision Making

# %%
decision_making_df = pd.read_csv("decision_making.csv")
decision_making_df /= 1000000 # convert ns to ms
decision_making_df.describe()
# Out:
#        primary_system  secondary_system  emergency_system  \
# count     3735.000000       3735.000000       3735.000000
# mean         0.049486          0.063975          0.003286
# std          0.227237          0.257341          0.057547
# min          0.000000          0.000000          0.000000
# 25%          0.000000          0.000000          0.000000
# 50%          0.000000          0.000000          0.000000
# 75%          0.000000          0.000000          0.000000
# max          1.515900          1.578100          1.125200
#
#        inventory_management_system
# count                  3735.000000
# mean                      0.047422
# std                       0.222166
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                       1.509600

# %%
decision_making_df["primary_system"].hist()
# Out:
# <AxesSubplot:>

# %%
decision_making_df["secondary_system"].hist()
# Out:
# <AxesSubplot:>

# %%
decision_making_df["emergency_system"].hist()
# Out:
# <AxesSubplot:>

# %%
decision_making_df["inventory_management_system"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Control

# %%
control_df = pd.read_csv("control.csv")
control_df["time"] /= 1000000 # converting from ns to ms
control_times = {k: v for (k, v) in control_df.groupby('type')}

# %%
for name, time_df in control_times.items():
    print(name)
    print(time_df.describe())
    print("\n\n")
# Out:
# continue_action
#               time
# count  3722.000000
# mean      0.020509
# std       0.195190
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       5.982500
#
#
#
# control
#               time
# count  3735.000000
# mean      0.043916
# std       0.251042
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       5.982500
#
#
#
# explore
#             time
# count  22.000000
# mean    0.093864
# std     0.293903
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     0.000000
# max     1.003000
#
#
#
# go_towards
#              time
# count  128.000000
# mean     0.056141
# std      0.259689
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.572300
#
#
#
# pick_up
#             time
# count  15.000000
# mean    0.066653
# std     0.258147
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     0.000000
# max     0.999800

# %%
for name, time_df in control_times.items():
    plt.figure()
    axes = time_df["time"].hist()
    axes.set_title(name)

# %% [markdown]
# ### Action

# %%
action_df = pd.read_csv("action.csv")
action_df /= 1000000 # convert ns to ms
action_df.describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.85, 0.9, 0.95, 0.975, 0.99, 0.999])
# Out:
#                act
# count  3735.000000
# mean      4.727258
# std      14.770213
# min       0.000000
# 25%       1.000600
# 50%       1.408100
# 75%       2.435100
# 80%       2.683920
# 85%       3.395480
# 90%       6.006980
# 95%      32.154590
# 97.5%    41.338850
# 99%      46.406132
# 99.9%   212.966187
# max     359.056100

# %%
action_df["act"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Time plots

# %%
perception_df["create_objects"].plot()
# Out:
# <AxesSubplot:>

# %%
perception_df["hide_huds"].plot()
# Out:
# <AxesSubplot:>

# %%
perception_df["process_frame"].plot()
# Out:
# <AxesSubplot:>

# %%
perception_df["put_in_debug_queue"].plot()
# Out:
# <AxesSubplot:>

# %%
perception_df["screenshot"].plot()
# Out:
# <AxesSubplot:>

# %%
segmentation_df["process_frame"].plot()
# Out:
# <AxesSubplot:>

# %%
segmentation_df["put_in_debug_queue"].plot()
# Out:
# <AxesSubplot:>

# %%
segmentation_df["screenshot"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_df["handle_detected_objects_queue"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_df["handle_segmentation_queue"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_df["slam_predict"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_df["update_clock"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_df["update_player_model"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_df["update_world_model"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_df["use_received_segmentation_info"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_df["use_received_yolo_info"].plot()
# Out:
# <AxesSubplot:>

# %%
player_model_df["update"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["add_object"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["create_object"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["decide_player_position"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["finish_cycle"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["get_all_of"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["get_closest_unexplored_chunk"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["get_current_chunks"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["handle_mob_at_position"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["handle_yolo_info"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["local_to_global_position"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["matched_object"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["mob_detected"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["process_segmentation_image"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["recheck_object_chunk"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["start_cycle"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["update"].plot()
# Out:
# <AxesSubplot:>

# %%
world_model_times["warp_image_to_ground"].plot()
# Out:
# <AxesSubplot:>

# %%
decision_making_df["emergency_system"].plot()
# Out:
# <AxesSubplot:>

# %%
decision_making_df["inventory_management_system"].plot()
# Out:
# <AxesSubplot:>

# %%
decision_making_df["primary_system"].plot()
# Out:
# <AxesSubplot:>

# %%
decision_making_df["secondary_system"].plot()
# Out:
# <AxesSubplot:>

# %%
control_times["continue_action"].plot()
# Out:
# <AxesSubplot:>

# %%
control_times["control"].plot()
# Out:
# <AxesSubplot:>

# %%
control_times["explore"].plot()
# Out:
# <AxesSubplot:>

# %%
control_times["go_towards"].plot()
# Out:
# <AxesSubplot:>

# %%
control_times["pick_up"].plot()
# Out:
# <AxesSubplot:>

# %%
action_df["act"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_slam_df["slam_dt"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_slam_phases_df["calc_mahal_dists"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_slam_phases_df["slam_match_known"].plot()
# Out:
# <AxesSubplot:>

# %%
modeling_slam_phases_df["p1"].plot()
# Out:
# <AxesSubplot:>
